# %% [markdown]
# <a href="https://colab.research.google.com/github/KristinaIgorevna/Phyton-analyst-/blob/main/Sem3HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Задание 1
#
# ### 1.1 Создать новый признак price_per_sq_lot, который будет содержать среднюю стоимость за один кв. метр общей площади

# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df['price_per_sq_lot'] = df['price']/df['sqft_lot']
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      1180.0              0
# 1      7242     2.0           0     0  ...      2170.0            400
# 2     10000     1.0           0     0  ...       770.0              0
# 3      5000     1.0           0     0  ...      1050.0            910
# 4      8080     1.0           0     0  ...      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ###1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома

# %%
renovation = lambda x, y: y-x if y != 0 else 0
df['delta_renovated'] = df.apply(lambda x: renovation(x.yr_built, x.yr_renovated), axis=1)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# ###1.3 Создать признаки года продажи, месяца продажи

# %%
df['year_sold'] = df['date'].apply(lambda x: int(x[:4]))
df['month_sold'] = df['date'].apply(lambda x: int(x[4:6]))
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# 3      5000     1.0           0     0  ...             0    98136  47.5208
# 4      8080     1.0           0     0  ...             0    98074  47.6168
#
# ...

# %% [markdown]
# ###1.4 Удалите признаки date, zipcode, lat, long

# %%
df.drop(columns=['date', 'zipcode', 'lat', 'long'], inplace=True)

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...      1180.0              0      1955
# 1           0     0          3  ...      2170.0            400      1951
# 2           0     0          3  ...       770.0              0      1933
# 3           0     0          5  ...      1050.0            910      1965
# 4           0     0          3  ...      1680.0              0      1987
#
# ...

# %% [markdown]
# ##Задание 2
#
# ###Создайте датафрейм с клиентами

# %%
clients = pd.DataFrame({
    'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295, 939, 3840,  280,   20, 4332, 3475, 4213, 3113, 4809, 2134, 2242, 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
    'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060, 1189000207, 6821600300, 7137950720, 9510920050, 6131600255, 5428000070, 1788800910, 8100400160, 3123049142, 6306800010, 5083000375, 7920100025, 1951600150,  809001400,  339600110, 1622049154, 1099600250, 8563000110, 2768100205, 3995700435, 8861700030, 3303980210, 7731100066, 8146100580,  825069097, 3889100029, 9524100196]
})
clients.head()
# Out:
#    client_id    house_id
# 0       1459  8965450190
# 1       4684  6823100225
# 2       3498  5104540330
# 3       3942  2131701075
# 4       4535  1522700060

# %% [markdown]
# ###2.1 Присоедините к таблице clients данные по домам через метод join

# %%
df_id = df.set_index('id')
clients_id = clients.set_index('house_id')
clients_id.join(df_id).reset_index()
# Out:
#          index  client_id      price  bedrooms  bathrooms  sqft_living  \
# 0    339600110       4809   395000.0         3       2.50         1610
# 1    809001400       3113   925000.0         3       1.00         1630
# 2    825069097       1764   770000.0         3       2.50         2650
# 3   1099600250       2242   260000.0         3       1.75         1710
# 4   1189000207       2308   387000.0         2       2.50         1170
# 5   1522700060       4535   518000.0         4       2.75         2520
# 6   1622049154       2134   289900.0         3       1.75         1899
# 7   1788800910        939   190000.0         3       1.00         1200
# 8   1951600150       4213   180000.0         3       1.00         1610
# 9   2131701075       3942   420000.0         3       1.75         1720
# 10  2768100205       4929   519000.0         4       2.50         1950
# 11  3123049142        280   452000.0         3       2.25         2600
# ...

# %% [markdown]
# ###2.2 Присоедините к таблице clients данные по домам через метод merge

# %%
merged = clients.merge(df,left_on='house_id', right_on='id')
merged
# Out:
#     client_id    house_id          id      price  bedrooms  bathrooms  \
# 0        1459  8965450190  8965450190   295000.0         3       2.50
# 1        4684  6823100225  6823100225   700000.0         4       1.75
# 2        3498  5104540330  5104540330   679000.0         4       2.50
# 3        3942  2131701075  2131701075   420000.0         3       1.75
# 4        4535  1522700060  1522700060   518000.0         4       2.75
# 5        2308  1189000207  1189000207   387000.0         2       2.50
# 6        2866  6821600300  6821600300   886000.0         3       2.25
# 7        2765  7137950720  7137950720   339100.0         4       2.50
# 8        1472  9510920050  9510920050   725000.0         3       2.50
# 9        4236  6131600255  6131600255   202500.0         3       2.00
# 10       2295  5428000070  5428000070   770000.0         5       3.50
# 11        939  1788800910  1788800910   190000.0         3       1.00
# ...

# %% [markdown]
# ##Задание 3
#
# ###3.1 Найдите среднюю стоимость домов в зависимости от количества спален. Отсортируйте от меньшей стоимости к большей

# %%
price_bedrooms = df.groupby('bedrooms').aggregate('price').mean().reset_index().sort_values('price')
price_bedrooms
# Out:
#     bedrooms         price
# 1          1  3.176429e+05
# 2          2  4.013727e+05
# 0          0  4.095038e+05
# 3          3  4.662321e+05
# 11        11  5.200000e+05
# 4          4  6.354195e+05
# 12        33  6.400000e+05
# 5          5  7.865998e+05
# 10        10  8.193333e+05
# 6          6  8.255206e+05
# 9          9  8.939998e+05
# 7          7  9.511847e+05
# 8          8  1.105077e+06

# %% [markdown]
# ###3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
price_state = df.groupby('condition').agg({'price': ['min', 'mean', 'max']})
price_state
# Out:
#               price
#                 min           mean        max
# condition
# 1           78000.0  334431.666667  1500000.0
# 2           80000.0  327287.145349  2555000.0
# 3           75000.0  542012.578148  7062500.0
# 4           89000.0  521200.390033  7700000.0
# 5          110000.0  612418.089359  3650000.0

# %% [markdown]
# ###3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
houses_view = df.groupby(['waterfront', 'view']).aggregate('id').count()
houses_view
# Out:
# waterfront  view
# 0           0       19489
#             1         331
#             2         955
#             3         491
#             4         184
# 1           1           1
#             2           8
#             3          19
#             4         135
# Name: id, dtype: int64

# %%
df.pivot_table(index='waterfront', columns='view',
               values='id', aggfunc='count',
               fill_value=0)
# Out:
# view            0    1    2    3    4
# waterfront
# 0           19489  331  955  491  184
# 1               0    1    8   19  135

# %% [markdown]
# ###3.4 Каких домов в зависимости от этажности и количества спален больше?

# %%
houses_floor_rooms = df.groupby(['floors', 'bedrooms']).aggregate('id').count().reset_index().sort_values('id', ascending=False)
houses_floor_rooms
# Out:
#     floors  bedrooms    id
# 3      1.0         3  5455
# 23     2.0         4  3682
# 22     2.0         3  3118
# 4      1.0         4  2383
# 2      1.0         2  1951
# 13     1.5         3   786
# 24     2.0         5   775
# 14     1.5         4   698
# 5      1.0         5   605
# 21     2.0         2   497
# 42     3.0         3   405
# 15     1.5         5   185
# 12     1.5         2   182
# 1      1.0         1   162
# 41     3.0         2   123
# 25     2.0         6   119
# 6      1.0         6   104
# 43     3.0         4    61
# 34     2.5         4    58
# 33     2.5         3    56
# 16     1.5         6    30
# 35     2.5         5    23
# 11     1.5         1    21
# 26     2.0         7    19
# 36     2.5         6    14
# 44     3.0         5    13
# 20     2.0         1    12
# 7      1.0         7     9
# 17     1.5         7     7
# 19     2.0         0     6
# 27     2.0         8     6
# 45     3.0         6     5
# 8      1.0         8     5
# ...

# %%
df.pivot_table(index='bedrooms', columns='floors',
               values='id', aggfunc='count',
               fill_value=0)
# Out:
# floors     1.0  1.5   2.0  2.5  3.0  3.5
# bedrooms
# 0            4    0     6    0    2    1
# 1          162   21    12    1    3    0
# 2         1951  182   497    5  123    2
# 3         5455  786  3118   56  405    4
# 4         2383  698  3682   58   61    0
# 5          605  185   775   23   13    0
# 6          104   30   119   14    5    0
# 7            9    7    19    2    1    0
# 8            5    1     6    0    0    1
# 9            0    0     4    2    0    0
# 10           1    0     2    0    0    0
# 11           0    0     1    0    0    0
# 33           1    0     0    0    0    0

# %% [markdown]
# ###3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
houses_condition = df.groupby(['condition', 'grade']).aggregate('price').median()
houses_condition
# Out:
# condition  grade
# 1          1         142000.0
#            4         150000.0
#            5         190000.0
#            6         255000.0
#            7         403500.0
#            8         932500.0
# 2          3         280000.0
#            4         145000.0
#            5         180000.0
#            6         235000.0
#            7         305000.0
#            8         429000.0
#            9         715000.0
#            10       1752500.0
# 3          3          75000.0
#            4         205000.0
#            5         234475.0
#            6         265000.0
#            7         357500.0
#            8         485000.0
#            9         689000.0
#            10        890000.0
#            11       1209500.0
#            12       1807500.0
#            13       2888000.0
# 4          4         238525.0
#            5         229975.0
#            6         295000.0
#            7         390000.0
#            8         571250.0
# ...

# %%
df.pivot_table(index='condition', columns='grade',
               values='price', aggfunc='median',
               fill_value=0)
# Out:
# grade          1       3       4       5       6       7       8        9   \
# condition
# 1          142000       0  150000  190000  255000  403500  932500        0
# 2               0  280000  145000  180000  235000  305000  429000   715000
# 3               0   75000  205000  234475  265000  357500  485000   689000
# 4               0       0  238525  229975  295000  390000  571250   823500
# 5               0  262000       0  227450  285475  456000  696000  1078000
#
# grade           10       11       12       13
# condition
# 1                0        0        0        0
# 2          1752500        0        0        0
# 3           890000  1209500  1807500  2888000
# 4          1030000  1685000  2125000  5750000
# 5          1650000  2050000  1990000        0
